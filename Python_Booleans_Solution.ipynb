# %% [markdown]
# <a href="https://colab.research.google.com/github/mic5678/GitHub---Hosting-Hwk-My-first-shecodes-project/blob/main/Python_Booleans_Solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
height = 170
age = 31

print(height != 160) # True
print(height > 170 and age > 12) # False
print(height < 170 or age >= 12) # True
print(height >= 170 and age >= 31) # True
print(not(height >= 170 and age >= 31)) # False
# Out:
# True
# False
# True
# True
# False
